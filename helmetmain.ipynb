# %%
import cv2
import pandas as pd
from ultralytics import YOLO
import cvzone
import numpy as np

# %%
model=YOLO(r'D:\langchain\helmet safety\yolov8helmetdetection-main\best.pt')

def RGB(event, x, y, flags, param):
    if event == cv2.EVENT_MOUSEMOVE :  
        point = [x, y]
        print(point)
  
        

cv2.namedWindow('RGB')
cv2.setMouseCallback('RGB', RGB)
cap=cv2.VideoCapture(r'D:\langchain\helmet safety\yolov8helmetdetection-main\he2.mp4')


my_file = open(r"D:\langchain\helmet safety\yolov8helmetdetection-main\coco1.txt", "r")
data = my_file.read()
class_list = data.split("\n") 
#print(class_list)

count=0

while True:    
    ret,frame = cap.read()
    if not ret:
        break
    count += 1
    if count % 3 != 0:
        continue
    frame=cv2.resize(frame,(1020,500))
   

    results=model.predict(frame)
 #   print(results)
    a=results[0].boxes.data
    px=pd.DataFrame(a).astype("float")
#    print(px)
    
    list=[]
    for index,row in px.iterrows():
#        print(row)
 
        x1=int(row[0])
        y1=int(row[1])
        x2=int(row[2])
        y2=int(row[3])
        d=int(row[5])
        c=class_list[d]
 
      
        cv2.rectangle(frame,(x1,y1),(x2,y2),(255,0,255),2)
        cvzone.putTextRect(frame,f'{c}',(x1,y1),1,1)


    cv2.imshow("RGB", frame)
    if cv2.waitKey(1)&0xFF==27:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 416x800 5 helmets, 582.3ms
# Speed: 15.0ms preprocess, 582.3ms inference, 10.0ms postprocess per image at shape (1, 3, 416, 800)
#
# 0: 416x800 5 helmets, 459.2ms
# Speed: 9.1ms preprocess, 459.2ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 800)
#
# 0: 416x800 6 helmets, 456.3ms
# Speed: 6.9ms preprocess, 456.3ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 800)
#
# 0: 416x800 5 helmets, 443.0ms
# Speed: 7.0ms preprocess, 443.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 800)
#
# 0: 416x800 5 helmets, 443.4ms
# Speed: 7.6ms preprocess, 443.4ms inference, 4.4ms postprocess per image at shape (1, 3, 416, 800)
#
# 0: 416x800 5 helmets, 454.0ms
# Speed: 5.8ms preprocess, 454.0ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 800)
#
# 0: 416x800 5 helmets, 447.5ms
# Speed: 7.8ms preprocess, 447.5ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 800)
#
# 0: 416x800 4 helmets, 440.3ms
# ...
